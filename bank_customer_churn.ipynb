# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ariha\OneDrive - IIT Kanpur\Desktop\WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.drop(['customerID'], inplace=True, axis='columns')
df.sample(4)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4259  Female              0      No         No       3          Yes
# 6948  Female              0      No         No      47          Yes
# 4601    Male              0      No         No      45          Yes
# 2155  Female              0     Yes         No      30          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 4259            No              No  No internet service  No internet service
# 6948            No     Fiber optic                  Yes                   No
# 4601           Yes     Fiber optic                   No                   No
# 2155           Yes     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 4259  No internet service  No internet service  No internet service
# 6948                  Yes                  Yes                  Yes
# ...

# %%
df.shape
# Out:
# (7043, 20)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
pd.to_numeric(df['TotalCharges'],errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df[df['TotalCharges']==" "]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df = df[df.TotalCharges!=" "]
df.reset_index()
df['TotalCharges']=pd.to_numeric(df['TotalCharges'])
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 4095    Male              0      No         No       3          Yes
# 5029  Female              0     Yes         No       7          Yes
# 6317    Male              0      No         No       1          Yes
# 1323  Female              0     Yes         No      71          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 4095            No     Fiber optic                  Yes                   No
# 5029            No             DSL                  Yes                   No
# 6317           Yes     Fiber optic                   No                  Yes
# 1323           Yes              No  No internet service  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 4095                   No                  Yes                   No
# 5029                   No                   No                   No
# ...

# %%
for col in df:
    print(col , df[col].unique())
# Out:
# gender ['Female' 'Male']
# SeniorCitizen [0 1]
# Partner ['Yes' 'No']
# Dependents ['No' 'Yes']
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService ['No' 'Yes']
# MultipleLines ['No phone service' 'No' 'Yes']
# InternetService ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ['No' 'Yes' 'No internet service']
# OnlineBackup ['Yes' 'No' 'No internet service']
# DeviceProtection ['No' 'Yes' 'No internet service']
# TechSupport ['No' 'Yes' 'No internet service']
# StreamingTV ['No' 'Yes' 'No internet service']
# StreamingMovies ['No' 'Yes' 'No internet service']
# Contract ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling ['Yes' 'No']
# PaymentMethod ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# ...

# %%
df.replace('No internet service','No', inplace=True)
df.replace('No phone service','No', inplace=True)

# %%
df.shape
# Out:
# (7032, 20)

# %%
for col in df:
    print(col , df[col].unique())
# Out:
# gender ['Female' 'Male']
# SeniorCitizen [0 1]
# Partner ['Yes' 'No']
# Dependents ['No' 'Yes']
# tenure [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService ['No' 'Yes']
# MultipleLines ['No' 'Yes']
# InternetService ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ['No' 'Yes']
# OnlineBackup ['Yes' 'No']
# DeviceProtection ['No' 'Yes']
# TechSupport ['No' 'Yes']
# StreamingTV ['No' 'Yes']
# StreamingMovies ['No' 'Yes']
# Contract ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling ['Yes' 'No']
# PaymentMethod ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn ['No' 'Yes']

# %%
df.replace({'No':0,'Yes':1}, inplace=True)
df.replace({'Female':0,'Male':1}, inplace=True)
df.sample(4)
# Out:
# C:\Users\ariha\AppData\Local\Temp\ipykernel_7344\626383350.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'No':0,'Yes':1}, inplace=True)
# C:\Users\ariha\AppData\Local\Temp\ipykernel_7344\626383350.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Female':0,'Male':1}, inplace=True)
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 3395       1              0        0           0      62             1
# ...

# %%
cols = ['InternetService','Contract','PaymentMethod']
df=pd.get_dummies(data=df,dtype=int)
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 690        1              0        0           0       1             1
# 956        0              0        1           1      71             1
# 438        1              0        1           0      35             1
# 4843       1              0        1           1      69             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 690               0               0             0                 0  ...
# 956               1               0             0                 0  ...
# 438               1               0             0                 0  ...
# 4843              0               0             0                 0  ...
#
#       InternetService_0  InternetService_DSL  InternetService_Fiber optic  \
# 690                   1                    0                            0
# 956                   1                    0                            0
# ...

# %%
df.shape
# Out:
# (7032, 27)

# %%
df.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_0                            int32
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

colms = ['tenure','MonthlyCharges','TotalCharges']

scale = MinMaxScaler()
df[colms] = scale.fit_transform(df[colms])

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 2603       0              0        0           0  1.000000             1
# 1554       1              0        0           0  0.352113             1
# 3841       1              1        1           0  0.492958             1
# 772        0              0        0           0  0.000000             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2603              1               1             1                 1  ...
# 1554              0               0             0                 0  ...
# 3841              1               0             1                 0  ...
# 772               0               0             0                 0  ...
#
#       InternetService_0  InternetService_DSL  InternetService_Fiber optic  \
# 2603                  0                    0                            1
# 1554                  1                    0                            0
# ...

# %%
x = df.drop(['Churn'],axis='columns')
y = df['Churn']

# %%
x.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 1617       1              0        0           0  0.366197             1
# 3869       1              0        1           0  0.690141             1
# 4599       0              0        1           1  0.718310             1
# 2476       1              0        1           0  0.957746             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 1617              1               0             0                 1  ...
# 3869              1               0             1                 0  ...
# 4599              0               0             0                 1  ...
# 2476              0               1             1                 1  ...
#
#       InternetService_0  InternetService_DSL  InternetService_Fiber optic  \
# 1617                  0                    1                            0
# 3869                  0                    0                            1
# ...

# %%
x.shape
# Out:
# (7032, 26)

# %%
y.sample(4)
# Out:
# 849     0
# 343     0
# 2672    0
# 3301    1
# Name: Churn, dtype: int64

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(20,input_shape=(26,),activation='relu'),
    keras.layers.Dense(20,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid'),
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# c:\CODE\PYTHON_CODE\.venv\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test ,y_train, y_test = train_test_split(x,y)

# %%
x_train.shape
# Out:
# (5274, 26)

# %%
x_test.shape
# Out:
# (1758, 26)

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8613 - loss: 0.3029
# Epoch 2/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8481 - loss: 0.3125
# Epoch 3/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8542 - loss: 0.3106
# Epoch 4/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8582 - loss: 0.3006
# Epoch 5/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3070
# Epoch 6/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8713 - loss: 0.2897
# Epoch 7/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8618 - loss: 0.2976
# Epoch 8/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8610 - loss: 0.2981
# Epoch 9/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8613 - loss: 0.3018
# Epoch 10/100
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8566 - loss: 0.3059
# Epoch 11/100
# ...

# %%
model.evaluate(x_train,y_train)
# Out:
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.8673 - loss: 0.2847
# [0.27842941880226135, 0.8703071475028992]

# %%
model.evaluate(x_test,y_test)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - accuracy: 0.7955 - loss: 0.4567
# [0.46169957518577576, 0.7946529984474182]
